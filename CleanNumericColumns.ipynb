# %% [markdown]
# # Next
#
# 1. Split up column 40 into 1 or 2 columns: "TotalCost" and "CostPerKg". However - that would result in effectively two different data sets.
# 2. Convert "TotalCost" units into millions/thousands of shillings? Depends what the magnitude is. Otherwise, leave as raw numbers.
#
# ## Main Income cols to clean
#
# 1. ~~Q38.CashCropEarnings~~
# 2. ~~Q61.CropEarning~~
# 3. ~~Q69.AmountEarnedCattle~~
# 4. ~~Q72.TotalEarningCattle [note I don't know the difference between Q69 and Q72; some people have given same answers for both, some people haven't...]~~
# 5. ~~Q113.CostOfChange~~
# 6. ~~Q118.CostStarting~~

# %%
import csv
import pandas as pd
import numpy as np
import re

df = pd.read_csv('DataPrep/UgandaClean.csv')
df2 = pd.read_csv('DataPrep/KenyaClean.csv')

# %%
df.columns[0:20]
# Out:
# Index([u'Unnamed: 0', u'Unnamed: 0.1', u'SbjNum', u'Date', u'Srvyr',
#        u'Duration', u'Upload', u'Latitude', u'Longitude', u'UTCDiff',
#        u'VStart', u'VEnd', u'Q1.District', u'Q3.CoopSociety', u'Q4.Village',
#        u'Q5.MembershipNumber', u'Q7.ProducerOrg', u'Q8.Consent', u'Q10.Sex',
#        u'Q11.Age'],
#       dtype='object')

# %%
df2.columns[0:20]
# Out:
# Index([u'Unnamed: 0', u'SbjNum', u'Date', u'Srvyr', u'Duration', u'Upload',
#        u'Latitude', u'Longitude', u'UTCDiff', u'VStart', u'VEnd',
#        u'Q1.District', u'Q3.CoopSociety', u'Q4.Village',
#        u'Q5.MembershipNumber', u'Q7.ProducerOrg', u'Q8.Consent', u'Q10.Sex',
#        u'Q11.Age', u'Q12.Education'],
#       dtype='object')

# %%
# Export unique values

target_cols = ['Q21','Q93', 'Q28', 'Q95', 'Q97', 'Q99', 'Q147', 'Q148', 'Q150', 'Q162', 'Q163', 'Q165', 'Q166', 'Q170', 'Q171']


find_cols = [col for target in target_cols for col in df.columns if target in col and not '.FreeText' in col and not '.Clean' in col]
find_cols
# Out:
# ['Q21.Income.Food.O1',
#  'Q21.Income.SchoolFees.O2',
#  'Q21.Income.MedicalBills.O3',
#  'Q21.Income.Clothes.O4',
#  'Q21.Income.Energy.O5',
#  'Q21.Income.Other.O6',
#  'Q21.Income.Other.O6.Text',
#  'Q93.BankAccountChallenges',
#  'Q28.FarmHealth.Text',
#  'Q95.BankLoanFacilityChallenges',
#  'Q97.BankCreditChallenges',
#  'Q99.SACCOChallenges',
#  'Q147.OtherInfoAreas',
#  'Q148.IdeasOfChanges',
#  'Q150.HelpToImplementChanges',
#  'Q162.MainChallengesOnFarm',
#  'Q163.SolutionsToAddressProblems',
#  'Q165.ShareNewFarmingPractice',
#  'Q165.ShareNewFarmingPractice.Other',
#  'Q166.ShareNewFarmingPractice.Example',
#  'Q170.ChallengesOfSharingInfo',
#  'Q171.MakeSharingEasier']

# %%
# Cols with nothing in them
'''


'''

def build_dataframe_from_uniques(source_dataframe, cols_to_export, target_file):
    uniques_dict = { col: pd.Series(pd.unique(source_dataframe[col].dropna())) for col in cols_to_export }
    uniques_df = pd.DataFrame.from_dict(uniques_dict)
    uniques_df = uniques_df.replace('-1', np.nan)
    uniques_df.to_csv(target_file)
    print 'exported to ' + target_file

cols_to_export = ['Q21.Income.Other.O6.Text',
                  'Q28.FarmHealth.Text',
  'Q93.BankAccountChallenges',
  'Q97.BankCreditChallenges', 
 'Q148.IdeasOfChanges', 
 'Q95.BankLoanFacilityChallenges',
 'Q99.SACCOChallenges',
 'Q147.OtherInfoAreas',
 'Q150.HelpToImplementChanges',
 'Q162.MainChallengesOnFarm',
 'Q163.SolutionsToAddressProblems',

 'Q166.ShareNewFarmingPractice.Example',
 'Q170.ChallengesOfSharingInfo',
 'Q171.MakeSharingEasier']



build_dataframe_from_uniques(df, cols_to_export,'DataPrep/Uganda_UniqueNarrativeDataValues.csv' )
build_dataframe_from_uniques(df2, cols_to_export,'DataPrep/Kenya_UniqueNarrativeDataValues.csv' )
# Out:
# exported to DataPrep/Uganda_UniqueNarrativeDataValues.csv
# exported to DataPrep/Kenya_UniqueNarrativeDataValues.csv

# %%
u_df = pd.read_csv('DataPrep/Kenya_UniqueNarrativeDataValues.csv')
u_df
# Out:
#      Unnamed: 0                                Q147.OtherInfoAreas  \
# 0             0                                             biogas
# 1             1           biogas ,record keeping,soil conservation
# 2             2                                 best dairy farming
# 3             3                     soil management,value addition
# 4             4                soil testing in my farm,bee keeping
# 5             5                                            soil ph
# 6             6                          water and soil management
# 7             7                                      dairy farming
# 8             8  Newer practises to improve farming, harvesting...
# 9             9                     I need to know more about soil
# 10           10  Record Keeping and tea plantations and management
# 11           11                Trainings on tea and value addition
# 12           12                                 Tea and Management
# 13           13  To get more produce from tea farming hence goo...
# 14           14                                    Tea productions
# 15           15                                                Tea
# 16           16                         Soil PH levels, composting
# 17           17  Fertility, soil conservation, irrigation and F...
# 18           18                               how to preserve milk
# 19           19  more of training on farm records and new farmi...
# 20           20                                                NaN
# 21           21  proper Records keeping,\nGood farming practice...
# 22           22  fishery  \nfarm segmentation to improve yield\...
# 23           23  cattle rearing \nbetter farming skills to incr...
# 24           24                    soil testing,\nfinancial access
# 25           25  record keeping\nsoil acidity,\nhow to improve ...
# 26           26  biogas\ngreenhouse\nwater filtration\npoultry ...
# 27           27  soil ph value that is salinity and acidity \nb...
# 28           28                 soil testing \nfertilizer \nbiogas
# 29           29  soil management\ntea plucking rounds\nfertiliz...
# ..          ...                                                ...
# 158         158                                                NaN
# 159         159                                                NaN
# 160         160                                                NaN
# 161         161                                                NaN
# 162         162                                                NaN
# 163         163                                                NaN
# 164         164                                                NaN
# 165         165                                                NaN
# 166         166                                                NaN
# 167         167                                                NaN
# 168         168                                                NaN
# 169         169                                                NaN
# 170         170                                                NaN
# 171         171                                                NaN
# 172         172                                                NaN
# 173         173                                                NaN
# 174         174                                                NaN
# 175         175                                                NaN
# 176         176                                                NaN
# 177         177                                                NaN
# 178         178                                                NaN
# 179         179                                                NaN
# 180         180                                                NaN
# 181         181                                                NaN
# 182         182                                                NaN
# 183         183                                                NaN
# 184         184                                                NaN
# 185         185                                                NaN
# 186         186                                                NaN
# 187         187                                                NaN
#
#      Q148.IdeasOfChanges                        Q150.HelpToImplementChanges  \
# 0                      1                                expertise to assist
# 1                      2                               to be trained by oep
# 2                    NaN                                expert  to train me
# 3                    NaN                            be provide with finance
# 4                    NaN                   being trained on soil management
# 5                    NaN                  expert to train me on tea farming
# 6                    NaN                 training on best farming practices
# 7                    NaN                        provided with  tea seedling
# 8                    NaN                        Financial help and training
# 9                    NaN  Getting newer seeds of tea because my type is ...
# 10                   NaN                                      Being trained
# 11                   NaN                  Support financially and trainings
# 12                   NaN                              Finances and training
# 13                   NaN                                           Finances
# 14                   NaN                             Finances and knowledge
# 15                   NaN                      Loans, marketing and training
# 16                   NaN        visit by the extension officers to the farm
# 17                   NaN                                      being trained
# 18                   NaN  training on best farming practice and acces to...
# 19                   NaN      financial support to purchase modern beehives
# 20                   NaN  to trained\nto be boosted financially so as to...
# 21                   NaN  accessibility to finance\nstorage facility\ntr...
# 22                   NaN                    financial support\nand training
# 23                   NaN  when trained on the new techniques\nbuy me a c...
# 24                   NaN    financial support to fund me start the business
# 25                   NaN  financing to enable land acquisition and also ...
# 26                   NaN        i request for seedling or financial support
# 27                   NaN  financial support to be granted to enable me d...
# 28                   NaN                                  access to finance
# 29                   NaN      to be assisted financial support and training
# ..                   ...                                                ...
# 158                  NaN                                                NaN
# 159                  NaN                                                NaN
# 160                  NaN                                                NaN
# 161                  NaN                                                NaN
# 162                  NaN                                                NaN
# 163                  NaN                                                NaN
# 164                  NaN                                                NaN
# 165                  NaN                                                NaN
# 166                  NaN                                                NaN
# 167                  NaN                                                NaN
# 168                  NaN                                                NaN
# 169                  NaN                                                NaN
# 170                  NaN                                                NaN
# 171                  NaN                                                NaN
# 172                  NaN                                                NaN
# 173                  NaN                                                NaN
# 174                  NaN                                                NaN
# 175                  NaN                                                NaN
# 176                  NaN                                                NaN
# 177                  NaN                                                NaN
# 178                  NaN                                                NaN
# 179                  NaN                                                NaN
# 180                  NaN                                                NaN
# 181                  NaN                                                NaN
# 182                  NaN                                                NaN
# 183                  NaN                                                NaN
# 184                  NaN                                                NaN
# 185                  NaN                                                NaN
# 186                  NaN                                                NaN
# 187                  NaN                                                NaN
#
#                              Q162.MainChallengesOnFarm  \
# 0                   workers sometime are not available
# 1    neighbours cattle coming to my farm,moles dest...
# 2              workers who pluck tea are not available
# 3                                              drought
# 4          drought,expensive fertilizers ,soil erosion
# 5                               drought,weeds and pest
# 6     workers are not available to pluck ,as i am sick
# 7                drought,no enough workers or pluckers
# 8                            finance to buy fertilizer
# 9    Prices of farm inputs are high and low income ...
# 10                  Weather, prices of farm implements
# 11                                               Weeds
# 12                                             Weather
# 13                              Weather and hailstones
# 14                    Workers/pluckers need more money
# 15                 Old clown tea lack good productions
# 16                        Pests, Weeds and Bad weather
# 17                           Weeds, Pests and diseases
# 18   Transportation of farm produce is far, weather...
# 19                                                pest
# 20           lack of knowledge and high cost of living
# 21   plucking labour constrains on flactuation of t...
# 22                             heavy rainfall\ndrought
# 23             poor communication to my fellow farmers
# 24    not knowing the practices how they are don fully
# 25                           drought and run off water
# 26                       heavy rainfall and hailstones
# 27   weather changes and heavy rainfall with less f...
# 28                                     weather changes
# 29                                                  gd
# ..                                                 ...
# 158                            LACK OF ENOUGH FINANCES
# 159  LESS KGS FROM TEA FARMING\nSOIL EROSION IN THE...
# 160         NOT ENOUGH FERTILIZERS\nINSUFFICIENT FUNDS
# 161  Hailstorms\nDrought\nFrost\nInsufficient funds...
# 162  Hailstorms\nCold weather\nLack of finances\nLo...
# 163  Hailstorms\nPests and diseases\nDrought\nSoil ...
# 164  Hailstorms\nFrost\nDrought\nPests and diseases...
# 165  Cold weather\nHailstorms\nProlonged drought ma...
# 166         Heavy rains,bad weather,pests and diseases
# 167  Pests and diseases,Lack of finances,hailstorms...
# 168  Pests and diseases,drought,cold weather,Lack o...
# 169                           Drought,lack of finances
# 170      Drought,Frost,finances,hailstorms,heavy rains
# 171  Funds,lack of training on some areas such as d...
# 172  Cold weather,price fluctuations,prolonged drou...
# 173  Cold weather,prolonged drought,heavy rains,ins...
# 174  Prolonged drought,frost,lack of knowledge on w...
# 175  Frost,high cost of labour,prolonged drought,lo...
# 176  Frost,hailstorms,prolonged drought,insufficien...
# 177  Frost,drought,hailstorms,pests and diseases,in...
# 178  Lack of training on how to,no market for some ...
# 179  Inadequate fertilizer because it is expensive,...
# 180  High cost of fertilizer hence insufficiency he...
# 181  Prolonged drought,heavy rains,soil erosion,wee...
# 182  Drought,hailstorms,price fluctuations for tea,...
# 183  electricity\nweeds on tea farm \nlow yield in ...
# 184  Frost,hailstorms,drought,lack of enough funds ...
# 185  Hailstorms,frost,drought,lack of enough fertil...
# 186  Prolonged drought,hailstorms,frost,cold weathe...
# 187  High cost of labour and fertilizer,frost,hails...
#
#                        Q163.SolutionsToAddressProblems  \
# 0                                   i look for  others
# 1                                                 none
# 2                                 weeding and spraying
# 3                                        i pluck alone
# 4                                   we pluck as family
# 5                                                 loan
# 6    Going out to look for jobs/labour to increase ...
# 7        Buy farm inputs in time during a cheap season
# 8    Leaving tea to grow and leaves/branches touche...
# 9                    Mulching and using organic manure
# 10                                                None
# 11        Uprooting and throwing them away in the road
# 12                          Seeking reliable labourers
# 13                 Planning to uproot old model of tea
# 14   Using mice straps, weeding, support to bananas...
# 15                                            Spraying
# 16   Uprooting bad weeds not destroyed by spraying ...
# 17                                             not yet
# 18                             diversify on food crops
# 19       i have tried to employ some on contract basis
# 20                      putt tarraces to prevent water
# 21                                            tarecess
# 22                                    building gabions
# 23                              put mulching materials
# 24                            construction of terraces
# 25                                                  dd
# 26               intercroping and  planting shed trees
# 27   manual weeding \nchemical use to solve pest an...
# 28   manual weeding and chemical weeding\ni request...
# 29   building trench to prevent  soil erosion,\nto ...
# ..                                                 ...
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
#
#                   Q166.ShareNewFarmingPractice.Example  \
# 0                                         biogas usage
# 1                    soil conservation, record keeping
# 2                                        dairy farming
# 3                                      soil management
# 4                         soil management, bee keeping
# 5                         soil erosion,weed management
# 6     soil management and training on best tea farming
# 7    New information I will trained or shown about ...
# 8       The soil management and new farming techniques
# 9                                        The teachings
# 10                            The new ideas of farming
# 11                                    Fertilizer usage
# 12                               New farming practises
# 13                             About how I was thought
# 14                          The new farming techniques
# 15   Telling farm practises I am aware of. New teac...
# 16                    How to increase their production
# 17                Weeding information, soil management
# 18                      how to do hydroponic practices
# 19                 how to improve on banana production
# 20    how to do and practice soil and water management
# 21                       how to improve farming of tea
# 22         news ways of milk processing before selling
# 23                           how to construct taracess
# 24                                             pruning
# 25                              how to get quality tea
# 26                                   not in a position
# 27                     placement of mulching materials
# 28                                       my neighbours
# 29   the new farming practices so that they also be...
# ..                                                 ...
# 158     A new farming practice that I have implemented
# 159  A new farming practice that I have implemented...
# 160                                  Kitchen gardening
# 161                  How to implement the new practise
# 162  Storage of pesticides,how to dress when sprayi...
# 163  A new farming practise that has helped to incr...
# 164                                        Tea farming
# 165  Growing of passion fruits,how to handle the su...
# 166  How to expand market for tea and encourage oth...
# 167  Green house farming to increase food productio...
# 168                 Planting of traditional vegetables
# 169  Spacing when planting tea,tree planting and wh...
# 170  A new farming practice that he has been taught...
# 171  How to prevent soil erosion,tea farming and ho...
# 172            Soil management,spacing in planting tea
# 173  A new farming practise that I have implemented...
# 174   installation of energy saving jiko(rocket stove)
# 175           How to increase produce from tea farming
# 176          Dairy farming and artificial insemination
# 177  Planting feeds such as fodder trees for the ca...
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
#
#                           Q170.ChallengesOfSharingInfo  \
# 0                 how to inform farmers on the project
# 1                                                 none
# 2                            distance to other farmers
# 3    Getting time for demonstration because they ta...
# 4            Others doesn't accept teachings/trainings
# 5                   Others may not implement teachings
# 6    Some people do not believe or implement farmin...
# 7    Some people don't accept teachings/training fr...
# 8                                            Logistics
# 9                         Transport and other expenses
# 10   Some people exposure and lack of information m...
# 11             Few people and delays in implementation
# 12   People may lack all the necessities to apply t...
# 13             Time management, finances and materials
# 14                   communiction is a major constrain
# 15            language barriers and poor communication
# 16                                drought\npoor prices
# 17                language barrier and education level
# 18               not really depent on the other farmer
# 19                                  poor communication
# 20            ilitrecy some of us did not go to school
# 21                                          negligents
# 22                                            language
# 23                        communication and negligence
# 24                                                 NaN
# 25         resistance by the recipient to the new idea
# 26   inadequate resources such as time and recipien...
# 27                          lack of resources to train
# 28   poor attendance to training and demonstration\...
# 29                                       no challenges
# ..                                                 ...
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
#
#                                 Q171.MakeSharingEasier  \
# 0                                 airtime to call them
# 1                                                 none
# 2                               posters to be provided
# 3                                              nothing
# 4                   information to be announced by oep
# 5                            finance on transportation
# 6                           i need to be trained first
# 7    Having group trainings and official visitors t...
# 8                                         I don't know
# 9                                Call them to seminars
# 10             Needs Demonstration farms and workshops
# 11                   Materials and demonstration farms
# 12                                   Financial Support
# 13                                            Finances
# 14   Logistics and give resource persons, training ...
# 15                          Demonstrations sites/farms
# 16   Doing regular visits to check the farmers' pro...
# 17              Financial and manual/materials support
# 18                  have a localised system of farming
# 19                    improve on communication systems
# 20        have the presentation on understandable mode
# 21                     improve on farmer communication
# 22               educate farmers on farming techniques
# 23                             visit farmers regularly
# 24        reduce adult iliteracy through teaching them
# 25                      educate us on faring practices
# 26   educate the farmers on the importance of other...
# 27                                  use farm promoters
# 28    have the meetings frequent in the buying centers
# 29                                                 NaN
# ..                                                 ...
# 158  Inviting trained personnel to come for the mee...
# 159  Training materials,involving the administratio...
# 160  Provision of funds for the farmers to make it ...
# 161  Organising seminars for farmers,Inviting train...
# 162  Training so that you can be able to train othe...
# 163  chief to sensitize farmers to come and learn t...
# 164  Seeking assistance from the chiefs in calling ...
# 165  Organising visits for farmers to demonstration...
# 166  Build a green house so that it can be a traini...
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
#
#                               Q21.Income.Other.O6.Text  \
# 0                                                loans
# 1                                             pluckers
# 2                                        Farming costs
# 3                                            Cow feeds
# 4                                          development
# 5                                         workers wage
# 6                                              farming
# 7                                         development
# 8                              development buying land
# 9    invest on developments, pay wages,contribute t...
# 10                                               wages
# 11                                  wages, development
# 12                                 wages, developments
# 13                              wages, improve my farm
# 14                           wages,saving,animal feeds
# 15                                              wages,
# 16                                       animals feeds
# 17                              animals feeds, savings
# 18           wages,savings,development, daily expenses
# 19                            development,wages,saving
# 20                                       wages,savings
# 21                     saving,development,animal feeds
# 22                          wages, savings, develoment
# 23              saving,development,daily home expenses
# 24                                  animal feeds,wages
# 25                        wages,animal  feeds,savings,
# 26                                wages, animal feeds,
# 27                                  wages,developments
# 28                 wages, developments, daily expenses
# 29   wages, animal feeds,expanding farming,communit...
# ..                                                 ...
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
#
#                                  Q28.FarmHealth.Text  \
# 0                                  tea is now mature
# 1                                          good rain
# 2                   drought has not been experienced
# 3             prolonged drought,hailstorms this year
# 4                                      storm,drought
# 5           lack of enough rain,expensive fertilizer
# 6                                  drought this year
# 7                                            drought
# 8                                        enough rain
# 9                          tea has matured this year
# 10                                  Minimal rainfall
# 11                                       Bad weather
# 12           We used fertilizers and steady rainfall
# 13                                           Waether
# 14                                           Weather
# 15         Produce from land was good and sufficient
# 16                  Good produce and health of crops
# 17                                      Good weather
# 18                                        Good crops
# 19                            Weather and composting
# 20                             Fertility degradation
# 21    due to heavy rainfall accomoanied byhailstones
# 22                   perserver drouth hit tea bushes
# 23                                   weather changes
# 24          heavy rainfall accompanied by hailstones
# 25                      increased kgs plucked so far
# 26                               poor tea production
# 27                                pruning of the tea
# 28                            planted new tea pushes
# 29                     reduced tea leaves production
# ..                                               ...
# 158                   Enough fertilizer,good weather
# 159  Use of sly from biogas,use of decomposed manure
# 160                                              NaN
# 161                                              NaN
# 162                                              NaN
# 163                                              NaN
# 164                                              NaN
# 165                                              NaN
# 166                                              NaN
# 167                                              NaN
# 168                                              NaN
# 169                                              NaN
# 170                                              NaN
# 171                                              NaN
# 172                                              NaN
# 173                                              NaN
# 174                                              NaN
# 175                                              NaN
# 176                                              NaN
# 177                                              NaN
# 178                                              NaN
# 179                                              NaN
# 180                                              NaN
# 181                                              NaN
# 182                                              NaN
# 183                                              NaN
# 184                                              NaN
# 185                                              NaN
# 186                                              NaN
# 187                                              NaN
#
#      Q93.BankAccountChallenges  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# ..                         ...
# 158                        NaN
# 159                        NaN
# 160                        NaN
# 161                        NaN
# 162                        NaN
# 163                        NaN
# 164                        NaN
# 165                        NaN
# 166                        NaN
# 167                        NaN
# 168                        NaN
# 169                        NaN
# 170                        NaN
# 171                        NaN
# 172                        NaN
# 173                        NaN
# 174                        NaN
# 175                        NaN
# 176                        NaN
# 177                        NaN
# 178                        NaN
# 179                        NaN
# 180                        NaN
# 181                        NaN
# 182                        NaN
# 183                        NaN
# 184                        NaN
# 185                        NaN
# 186                        NaN
# 187                        NaN
#
#                         Q95.BankLoanFacilityChallenges  \
# 0                        High repayments and interests
# 1     Unfriendly bank restrictions and poor tea prices
# 2             long quees\nhigh interest rate per month
# 3                                           long quees
# 4                                    no problem so far
# 5    damage of tea bushes by drought or hailstones ...
# 6                                       not affordable
# 7                                           not so far
# 8                                           no problem
# 9                     crop damages through bad weather
# 10                                                  ff
# 11   High interest rates charged by banks,\nlow cre...
# 12   high interest charged by banks\nlimited credit...
# 13   interest charged on loan\nfluctuating prices o...
# 14                                  not hard to access
# 15   interest rates are high,\nfluctuating tea yiel...
# 16      repayment period especially during hail damage
# 17   low  credit limit because my security is agric...
# 18                  credit limit\nrepayment challenges
# 19   repayment problem since tea yield varies depen...
# 20             low tea yield makes my credit limit low
# 21            limited credit limit\nlow value security
# 22                              interest rates is high
# 23                             interest rates are high
# 24   delay in remittance\nlow credit limit \nhigh i...
# 25   repayment period is low and high interest and ...
# 26           repayment during low is a great challenge
# 27   due to low crop yield  and fluctuating tea pri...
# 28            fluctuating crop yield lows credit limit
# 29       credit is limited because tea yield fluctuate
# ..                                                 ...
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
#
#                               Q97.BankCreditChallenges  \
# 0                             interest charged is high
# 1    less kilos affect payments of the loan and credit
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
#
#                                    Q99.SACCOChallenges
# 0                       Restrictions on loan repayment
# 1                                      Poor management
# 2                                                 None
# 3    Taking a lot of time to approve and disburse l...
# 4              long processing time with high interest
# 5                        limited credit limit by sacco
# 6                              restricted credit limit
# 7             limited credit limit\ndelayed remittance
# 8    restricted credit limit. it depends on deliver...
# 9             credit limit is low depends on my shares
# 10                            reduce production of tea
# 11   credit limit is limited by shares held\nrepayment
# 12       my share is my security thus low credit limit
# 13     loan value is limited by shares held\nrepayment
# 14                                        no challenge
# 15    delay to credit my account \ncredit limit is low
# 16                                                none
# 17              its not active,take time to given loan
# 18           Repayments during low season is a problem
# 19                   sometime there is no enough funds
# 20                          limitation of funds amount
# 21                reduced production increase interest
# 22            poor weather sometimes affect the income
# 23                   delay in disbursement of the loan
# 24                                so far no challenges
# 25     low production of tea sometimes affect payement
# 26               low credit limit depends on my shares
# 27          low amount of money disbursed by the sacco
# 28                                   no problem so far
# 29                            delay sometimes of money
# ..                                                 ...
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165                                                NaN
# 166                                                NaN
# 167                                                NaN
# 168                                                NaN
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178                                                NaN
# 179                                                NaN
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185                                                NaN
# 186                                                NaN
# 187                                                NaN
#
# [188 rows x 15 columns]

# %%
def compile(expression):
    return re.compile(expression, re.I)

def clean_amount_columns (row, column_name):
    input_value = row[column_name]
    
    
    if pd.isnull(input_value):
        return input_value 
    
    # global cleanup
    input_value = re.sub('\s', '', input_value)
    leading_string_pattern = compile('v')
    input_value = leading_string_pattern.sub('', input_value)
    
    commas_pattern = compile('^[\d\,]+$')
    commas_pattern_with_random_end_string = compile('^[\d\,]+[^\d]+$')
    m_pattern = compile('^\d{1,}(\.\d{1,})?m(illion|ilion)?(ugx)?')
    commas_and_currency_pattern = compile('^[\d\,]+(ugx|/=|shs)$')
    commas_and_currency_with_random_end_string = compile('^[\d\,]+(ugx|/=)[^\d]+$')
    no_numbers_pattern = compile('^[^\d]+$')
    

    replace_million = compile('m(illion|ilion)?(ugx)?')
    replace_comma = compile('(\,)')
    replace_currency = compile('(ugx|/=|shs)')
    replace_currency_with_random_string = compile('(ugx|/=|shs)[^\d]+')
    replace_random_end_string = compile('[^\d]+$')
    
    if commas_pattern.search(input_value):
        return float(replace_comma.sub('', input_value))
    elif m_pattern.search(input_value):
        number_only = float(replace_million.sub('', input_value)) * 1000000
        return number_only
    elif commas_and_currency_pattern.search(input_value):
        stripped_of_commas = replace_comma.sub('', input_value)
        return float(replace_currency.sub('', stripped_of_commas))
    elif commas_and_currency_with_random_end_string.search(input_value):
        stripped_of_commas = replace_comma.sub('', input_value)
        return float(replace_currency_with_random_string.sub('', stripped_of_commas))
    elif commas_pattern_with_random_end_string.search(input_value):
        stripped_of_commas = replace_comma.sub('', input_value)
        return float(replace_random_end_string.sub('', stripped_of_commas))
    elif re.search(no_numbers_pattern, input_value):
        return np.nan
    else:
        return input_value
    
def keep_free_text_only (row, column_name): 
    input_value = row[column_name]   
    if pd.isnull(input_value):
        return input_value 
    no_numbers_pattern = compile('^[^\d]*$')
    if no_numbers_pattern.search(input_value):
        return input_value
    else:
        return np.nan

# %%
# Q38, Q61, Q69, Q72, Q113, Q118
target_cols = ['Q38', 'Q61', 'Q69', 'Q72', 'Q113', 'Q118']

cols_to_clean = [col for target in target_cols for col in df.columns if target in col and not '.FreeText' in col and not '.Clean' in col]

cols_to_clean

#pd.unique(df[cols_to_clean[0]])
# Out:
# ['Q38.CashCropEarnings',
#  'Q61.CropEarning',
#  'Q69.AmountEarnedCattle',
#  'Q72.TotalEarningCattle',
#  'Q113.CostOfChange',
#  'Q118.CostStarting']

# %%
for col_name in cols_to_clean:
    clean_col_name = col_name+'.Clean'
    freetext_col_name = col_name+'.FreeText'

    df[freetext_col_name] = df.apply(lambda row:keep_free_text_only(row, col_name), axis=1)
    df[clean_col_name] = df.apply(lambda row: clean_amount_columns(row, col_name), axis=1)

    print(col_name, df[clean_col_name].apply(np.isreal).all(skipna=True))
# Out:
# ('Q38.CashCropEarnings', True)
# ('Q61.CropEarning', True)
# ('Q69.AmountEarnedCattle', False)
# ('Q72.TotalEarningCattle', True)
# ('Q113.CostOfChange', True)
# ('Q118.CostStarting', True)

# %%
# Use for investigating false columns
#pd.unique(df[clean_col_name])
#pd.unique(df[freetext_col_name])

# %%
[col for target in target_cols for col in df.columns if target in col]
# Out:
# ['Q38.CashCropEarnings',
#  'Q38.CashCropEarnings.FreeText',
#  'Q38.CashCropEarnings.Clean',
#  'Q61.CropEarning',
#  'Q61.CropEarning.FreeText',
#  'Q61.CropEarning.Clean',
#  'Q69.AmountEarnedCattle',
#  'Q69.AmountEarnedCattle.FreeText',
#  'Q69.AmountEarnedCattle.Clean',
#  'Q72.TotalEarningCattle',
#  'Q72.TotalEarningCattle.FreeText',
#  'Q72.TotalEarningCattle.Clean',
#  'Q113.CostOfChange',
#  'Q113.CostOfChange.FreeText',
#  'Q113.CostOfChange.Clean',
#  'Q118.CostStarting',
#  'Q118.CostStarting.FreeText',
#  'Q118.CostStarting.Clean']

# %%
#df.to_csv('DataPrep/UgandaClean.csv')
